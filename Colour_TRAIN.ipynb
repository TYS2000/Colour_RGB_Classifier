# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
from sklearn.model_selection import train_test_split

IMG_SIZE = 32
DATADIR = r'E:\COLOURS\train'
CATEGORIES =['Red','Blue','Green']
training_data = []

for category in CATEGORIES:
    path = os.path.join(DATADIR, category)
    class_num = CATEGORIES.index(category)
    print(class_num)

    for img in os.listdir(path):
        try:
            img_array = cv2.imread(os.path.join(path,img))
            new_array = cv2.resize(img_array,(IMG_SIZE, IMG_SIZE))
            training_data.append([new_array, class_num])
        except Exception as e:
            pass

import random
random.shuffle(training_data)
X = []
y = []

for features, label in training_data:  
    X.append(features) 
    y.append(label)

# X and y are currently of type list (list of python array), we will convert these to numpy array so we can feed it into our model.
X = np.array(X) 
y = np.array(y) 


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D

model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, kernel_size=(3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy',optimizer='Adam',metrics=['sparse_categorical_accuracy'])
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
model.save(r"E:\COLOURS\COLOURS_CNN.h5")

loss, acc = model.evaluate(X_test, y_test, verbose = 0)
print("Accuracy:",acc * 100)
# Out:
# 0
# 1
# 2
# Train on 2986 samples, validate on 747 samples
# Epoch 1/10
# 2986/2986 [==============================] - 6s 2ms/sample - loss: 1.0236 - sparse_categorical_accuracy: 0.9106 - val_loss: 0.0233 - val_sparse_categorical_accuracy: 0.9893
# Epoch 2/10
# 2986/2986 [==============================] - 4s 1ms/sample - loss: 0.0314 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.0566 - val_sparse_categorical_accuracy: 0.9853
# Epoch 3/10
# 2986/2986 [==============================] - 4s 1ms/sample - loss: 0.0904 - sparse_categorical_accuracy: 0.9853 - val_loss: 0.0157 - val_sparse_categorical_accuracy: 0.9973
# Epoch 4/10
# 2986/2986 [==============================] - 4s 1ms/sample - loss: 0.0492 - sparse_categorical_accuracy: 0.9863 - val_loss: 0.3778 - val_sparse_categorical_accuracy: 0.9585
# Epoch 5/10
# 2986/2986 [==============================] - 4s 1ms/sample - loss: 0.1185 - sparse_categorical_accuracy: 0.9735 - val_loss: 0.0118 - val_sparse_categorical_accuracy: 1.0000
# Epoch 6/10
# 2986/2986 [==============================] - 4s 1ms/sample - loss: 0.0363 - sparse_categorical_accuracy: 0.9903 - val_loss: 0.0600 - val_sparse_categorical_accuracy: 0.9585
# Epoch 7/10
# 2986/2986 [==============================] - 4s 1ms/sample - loss: 0.1441 - sparse_categorical_accuracy: 0.9742 - val_loss: 0.0292 - val_sparse_categorical_accuracy: 0.9987
# Epoch 8/10
# 2986/2986 [==============================] - 4s 1ms/sample - loss: 0.0443 - sparse_categorical_accuracy: 0.9903 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 0.9946
# Epoch 9/10
# 2986/2986 [==============================] - 4s 1ms/sample - loss: 0.0600 - sparse_categorical_accuracy: 0.9856 - val_loss: 0.1668 - val_sparse_categorical_accuracy: 0.9384
# Epoch 10/10
# 2986/2986 [==============================] - 4s 1ms/sample - loss: 0.0480 - sparse_categorical_accuracy: 0.9893 - val_loss: 4.8829e-04 - val_sparse_categorical_accuracy: 1.0000
# Accuracy: 100.0
